# %% [markdown]
# # データ解析のための統計モデリング入門

# %% [markdown]
# ## 1章 データを理解するためにモデルを作る

# %% [markdown]
# ### 1.1 統計モデル：なぜ「統計」な「モデル」？
#
# 統計モデルとは？
#
#  - __確率分布__を基本的な部品として利用 → データに見られるばらつきも表現可能
#  - 作成した統計モデルとデータがどれくらいうまくフィッティングしているのかも定量的に説明可能
#
#  ![概要図](images/1.1.jpg)
#
# Q. 統計モデルがなぜ必要なのか？
# A. データにもとづいて現象を説明したいため

# %% [markdown]
# ### 1.2 「ブラックボックスな統計解析」の悪夢
#
# ブラックボックスな統計解析 (引用 p.4, 5)
#
# - 「ゆーい差」が出るまで検定手法をひたすらとりかえる
# - データ中の観測値どうしの割算によって新しい「指標」をでっちあげる…「ゆーい差」がでるまで新発明をくりかえす
# - R2値は「説明力」なので，ひたすら1に近づければよい
# - 「等分散じゃない」とか文句をつけられたら，データを変数変換して回帰・ANOVAすればよい
# - あるいはめんどうになったら観測値どうしで割算値を作って，「ノンパラメトリック検定」をやればよい
# - 「検定を何度もやっているので多重比較だ」と文句をつけられれば，何でもかんでも多重検定法による補正をやればよい
# - 論文中でデータを示すときには何でも検定してP値をつける，P値が小さいほど自分の主張は正しい
#
# 本書の目的
#
# - このような恣意的な統計学を避ける
# - 解析の目的に沿いつつ，かつその構造に合致した統計モデルを構築

# %% [markdown]
# ### 1.3 この本の内容：一般化線形モデルの導入とそのベイズ的な拡張
#
# キーワード列挙
#
# - 確率分布 (probability distribution)
# - 最尤推定 (maximum likelihood estimation)
# - 一般化線形モデル (generalized linear model, GLM)
# - モデル選択 (model selection) におけるAIC
# - 最大対数尤度 (maximum log likelihood)
# - 尤度比検定 (likelihood ratio test)
# - ロジスティック回帰 (logistic regression)
# - 一般化線形混合モデル (generalized linear mixed model, GLMM)
# - マルコフ連鎖モンテカルロ法 (Markov chain Monte Carlo method, MCMC)
# - ベイズ統計モデル (Bayesian statistical model)
# - 階層ベイズモデル (hierarchical Bayesian model)

# %% [markdown]
# ### 1.4 この本に登場する訳語・記号・記法について
#
# 省略
#
# ### 1.5 この章のまとめと参考文献
#
# 省略
